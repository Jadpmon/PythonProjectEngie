# %%
from ClassProject import ExploreData, Model
import warnings; warnings.filterwarnings("ignore")

# %%
exploredata = ExploreData(dataframe_path='data.csv')
exploredata.info_data()
# Out:
#  ** format du dataframe (ligne,colonne) = (1460, 81) **
#
# ** description du data frame **
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# ...

# %%
exploredata.visualisation_count_category()
# Out:
#  ** COUNT DES VARIABLE CAT **

# %%
exploredata.visualisation_corr_matrix()
# Out:
# ** Matrice de correlation **

# %%
exploredata.columns_to_drop(['Id','PoolQC','MiscFeature','Alley','FireplaceQu','LotFrontage','Fence'])
# Out:
# ** Suppression des colonne :  ['Id', 'PoolQC', 'MiscFeature', 'Alley', 'FireplaceQu', 'LotFrontage', 'Fence']  **

# %%
exploredata.process_cat()
exploredata._dataframe = exploredata._dataframe.fillna(0)

# %%
from sklearn.metrics import make_scorer
import numpy as np
ML = Model(exploredata._dataframe)
ML.train_test_split('SalePrice')
ML.init_models()
def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
MAPE = make_scorer(mean_absolute_percentage_error)
ML.evaluation(MAPE)
# Out:
# GradientBoostingRegressor: 9.9095 (+/- 0.8994)
# RandomForestRegressor: 10.7389 (+/- 0.4578)
# DecisionTreeRegressor: 15.7941 (+/- 1.0139)
# SVR: 31.5910 (+/- 1.0990)
# KNeighborsRegressor: 17.9706 (+/- 1.0259)
# LinearRegression: 13.1470 (+/- 0.5942)
